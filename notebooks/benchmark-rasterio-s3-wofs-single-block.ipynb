# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import pickle
from types import SimpleNamespace
from utils import bench

# %%
data = pickle.load(open('results_-9_-18@8_2_threads-1.pickle', 'rb'))

print(bench.gen_stats_report(data.results, data.parameters))

bench.plot_results(data.results, 
                   fig=plt.figure(figsize=(12,8)));
# Out:
# -------------------------------------------------------------
# Tile: (-9,-18), block: 8,2, band 1
#    - blocks 256x256 uint8
#    - nthreads     1
# -------------------------------------------------------------
#
# Files read             : 1416
# Total data bytes       : 10,654,031
#   (excluding headers)
# Bytes per chunk        : 7524 [5557..17894] bytes
#
# Time:
#  per tile:
#   - total   174.406 [82.7.....2446.5] ms
#   - open    140.724 [62.1.....2400.6] ms 80.6%
#   - read     33.682 [11.4......727.9] ms 19.4%
#
#  total: 247 sec
# -------------------------------------------------------------
